# %% [markdown]
# <a href="https://colab.research.google.com/github/dainfinity/py_useful/blob/main/to_seireki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

df_year=df['年'].fillna('')
year_list=df_year.tolist()

for i in range(len(year_list)):
   if re.match('昭和',year_list[i]):
       year_list[i] = 1925 + int(re.sub(r'\D','',year_list[i]))    
   elif re.match('令和',year_list[i]):
       year_list[i] = 2018 + int(re.sub(r'\D','',year_list[i]))
   elif re.match('戦前',year_list[i]):
       year_list[i] = 1945
   elif re.match('平成',year_list[i]):
       year_list[i] = 1988 + int(re.sub(r'\D','',year_list[i])) 
  
   else:
     continue

df_seireki = pd.DataFrame({'西暦':year_list})
